# %% [markdown]
# ## Importing Dependencies

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel("/content/Product Recommendation engine.xlsx")
print(data.head())
# Out:
#    user_Id                email               product  rating
# 0    15889  cust15889@gmail.com  Medium-term deposits     3.5
# 1    15890  cust15890@gmail.com            Securities     3.0
# 2    15891  cust15891@gmail.com          Direct Debit     4.0
# 3    15892  cust15892@gmail.com       Payroll Account     2.0
# 4    15893  cust15893@gmail.com              Pensions     1.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2021 entries, 0 to 2020
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_Id  2021 non-null   int64
#  1   email    2021 non-null   object
#  2   product  2021 non-null   object
#  3   rating   2021 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 63.3+ KB

# %%
combine_cust_rating = data.dropna(axis = 0, subset = ['email'])
cust_ratingCount = (combine_cust_rating.
     groupby(by = ['email'])['rating'].
     count().
     reset_index().
     rename(columns = {'rating': 'totalRatingCount'})
     [['email', 'totalRatingCount']]
    )
cust_ratingCount.head()
# Out:
#                  email  totalRatingCount
# 0  cust15889@gmail.com                 2
# 1  cust15890@gmail.com                 1
# 2  cust15891@gmail.com                 1
# 3  cust15892@gmail.com                 2
# 4  cust15893@gmail.com                 2

# %%
cust_ratingCount
# Out:
#                     email  totalRatingCount
# 0     cust15889@gmail.com                 2
# 1     cust15890@gmail.com                 1
# 2     cust15891@gmail.com                 1
# 3     cust15892@gmail.com                 2
# 4     cust15893@gmail.com                 2
# ...                   ...               ...
# 1987  cust19664@gmail.com                 1
# 1988  cust19666@gmail.com                 1
# 1989  cust19668@gmail.com                 1
# 1990  cust19670@gmail.com                 1
# 1991  cust19672@gmail.com                 1
#
# [1992 rows x 2 columns]

# %%
data["rating"].describe
# Out:
# <bound method NDFrame.describe of 0       3.5
# 1       3.0
# 2       4.0
# 3       2.0
# 4       1.0
#        ...
# 2016    5.0
# 2017    3.0
# 2018    2.0
# 2019    4.0
# 2020    4.5
# Name: rating, Length: 2021, dtype: float64>

# %%
rating_with_totalRatingCount = data.merge(cust_ratingCount, left_on = 'email', right_on = 'email', how = 'left')
print(rating_with_totalRatingCount.head())
# Out:
#    user_Id                email               product  rating  \
# 0    15889  cust15889@gmail.com  Medium-term deposits     3.5
# 1    15890  cust15890@gmail.com            Securities     3.0
# 2    15891  cust15891@gmail.com          Direct Debit     4.0
# 3    15892  cust15892@gmail.com       Payroll Account     2.0
# 4    15893  cust15893@gmail.com              Pensions     1.0
#
#    totalRatingCount
# 0                 2
# 1                 1
# 2                 1
# 3                 2
# 4                 2

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
print(cust_ratingCount['totalRatingCount'].describe())
# Out:
# count   1992.000
# mean       1.015
# std        0.120
# min        1.000
# 25%        1.000
# 50%        1.000
# 75%        1.000
# max        2.000
# Name: totalRatingCount, dtype: float64

# %%
print(cust_ratingCount['totalRatingCount'].describe())
# Out:
# count   1992.000
# mean       1.015
# std        0.120
# min        1.000
# 25%        1.000
# 50%        1.000
# 75%        1.000
# max        2.000
# Name: totalRatingCount, dtype: float64

# %%
popularity_threshold = 2.0
rating_popular_product= rating_with_totalRatingCount.query('totalRatingCount >= @popularity_threshold')
rating_popular_product.head()
# Out:
#     user_Id                email               product  rating  \
# 0     15889  cust15889@gmail.com  Medium-term deposits   3.500
# 3     15892  cust15892@gmail.com       Payroll Account   2.000
# 4     15893  cust15893@gmail.com              Pensions   1.000
# 7     15889  cust15889@gmail.com      Current Accounts   4.500
# 10    15893  cust15893@gmail.com           Credit Card   2.000
#
#     totalRatingCount
# 0                  2
# 3                  2
# 4                  2
# 7                  2
# 10                 2

# %%
# First lets create a Pivot matrix

product_features_df = rating_with_totalRatingCount.pivot_table(index='product',columns='email',values='rating').fillna(0)
product_features_df.head()
# Out:
# email             cust15889@gmail.com  cust15890@gmail.com  \
# product
# Credit Card                     0.000                0.000
# Current Accounts                4.500                0.000
# Derivada Account                0.000                0.000
# Direct Debit                    0.000                0.000
# Funds                           0.000                0.000
#
# email             cust15891@gmail.com  cust15892@gmail.com  \
# product
# Credit Card                     0.000                0.000
# Current Accounts                0.000                0.000
# Derivada Account                0.000                0.000
# Direct Debit                    4.000                0.000
# Funds                           0.000                4.000
#
# email             cust15893@gmail.com  cust15894@gmail.com  \
# product
# Credit Card                     2.000                1.500
# Current Accounts                0.000                0.000
# ...

# %%
from scipy.sparse import csr_matrix

product_features_df_matrix = csr_matrix(product_features_df.values)

from sklearn.neighbors import NearestNeighbors


model_knn = NearestNeighbors(metric = 'cosine', algorithm = 'brute')
model_knn.fit(product_features_df_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
product_features_df.shape
# Out:
# (23, 1992)

# %%
query_index = np.random.choice(product_features_df.shape[0])
print(query_index)
distances, indices = model_knn.kneighbors(product_features_df.iloc[query_index,:].values.reshape(1, -1), n_neighbors = 6)
# Out:
# 5

# %%
product_features_df.head()
# Out:
# email             cust15889@gmail.com  cust15890@gmail.com  \
# product
# Credit Card                     0.000                0.000
# Current Accounts                4.500                0.000
# Derivada Account                0.000                0.000
# Direct Debit                    0.000                0.000
# Funds                           0.000                0.000
#
# email             cust15891@gmail.com  cust15892@gmail.com  \
# product
# Credit Card                     0.000                0.000
# Current Accounts                0.000                0.000
# Derivada Account                0.000                0.000
# Direct Debit                    4.000                0.000
# Funds                           0.000                4.000
#
# email             cust15893@gmail.com  cust15894@gmail.com  \
# product
# Credit Card                     2.000                1.500
# Current Accounts                0.000                0.000
# ...

# %%
for i in range(0, len(distances.flatten())):
    if i == 0:
        print('Recommendations for {0}:\n'.format(product_features_df.index[query_index]))
    else:
        print('{0}: {1}, with distance of {2}:'.format(i, product_features_df.index[indices.flatten()[i]], distances.flatten()[i]))
# Out:
# Recommendations for Guarantees:
#
# 1: Payroll, with distance of 0.9845120124517621:
# 2: Current Accounts, with distance of 0.9916611094611473:
# 3: Saving Account, with distance of 1.0:
# 4: Payroll Account, with distance of 1.0:
# 5: Pensions, with distance of 1.0:

# %% [markdown]
# # Pickle

# %%
import pickle

model = pickle.dump(product_features_df, open("Model_bank.pkl", "wb"))
